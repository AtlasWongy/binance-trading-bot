# %%
import json
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from binance.client import Client

# %%
f = open('config.json')
config = json.load(f)

client = Client(config["api_key"], config["secure_key"])
print("Connected to Binance successfully....")
# Out:
# Connected to Binance successfully....

# %%
# Set the time period and number of standard deviations for the calculations
time_period = 20
num_std_dev = 2

# %%
klines = client.get_historical_klines(config["currency"], Client.KLINE_INTERVAL_5MINUTE, "1 day ago UTC")

klines_dataframe = pd.DataFrame(
    klines, 
    columns=[
        'Open Time', 
        'Open', 
        'High', 
        'Low', 
        'Close', 
        'Volume',
        'Close Time',
        'Quote Asset',
        'Volume',
        'Number of Trades',
        'Taker buy base asset volume',
        'Taker buy quote asset volume'
    ])

# %%
display(klines_dataframe)
# Out:
#          Open Time           Open           High            Low  \
# 0    1670932200000  1287.86000000  1288.66000000  1287.06000000
# 1    1670932500000  1287.19000000  1288.00000000  1287.00000000
# 2    1670932800000  1287.45000000  1288.87000000  1287.45000000
# 3    1670933100000  1287.99000000  1288.46000000  1287.99000000
# 4    1670933400000  1288.22000000  1289.70000000  1287.20000000
# ..             ...            ...            ...            ...
# 283  1671017100000  1326.22000000  1327.16000000  1326.04000000
# 284  1671017400000  1326.69000000  1326.77000000  1325.52000000
# 285  1671017700000  1325.53000000  1325.53000000  1323.41000000
# 286  1671018000000  1324.21000000  1325.01000000  1323.63000000
# 287  1671018300000  1325.00000000  1325.01000000  1324.27000000
#
#              Close         Volume     Close Time       Quote Asset  Volume  \
# 0    1287.20000000   998.24180000  1670932499999  1285501.64463600    1190
# 1    1287.45000000   933.20550000  1670932799999  1201550.91262400    1036
# 2    1288.00000000  1271.40590000  1670933099999  1637662.38640100    1289
# 3    1288.22000000   719.95170000  1670933399999   927387.62332000     592
# 4    1287.62000000  1427.98540000  1670933699999  1839481.54335500    1041
# ..             ...            ...            ...               ...     ...
# 283  1326.68000000   391.00200000  1671017399999   518681.60312100     406
# 284  1325.53000000   488.57570000  1671017699999   647887.34980000     485
# 285  1324.21000000   931.77010000  1671017999999  1234124.30376100     904
# 286  1325.01000000   494.68260000  1671018299999   655082.57793000     527
# 287  1324.28000000   227.71030000  1671018599999   301670.13987600     254
#
#     Number of Trades Taker buy base asset volume Taker buy quote asset volume
# 0       314.66720000             405251.89531100                            0
# 1       345.63020000             445027.37913400                            0
# 2       517.36460000             666412.95455900                            0
# 3       377.42030000             486154.72935700                            0
# 4       525.44480000             676884.69325200                            0
# ..               ...                         ...                          ...
# 283     252.06560000             334368.72573700                            0
# 284      69.58440000              92284.52865500                            0
# 285     286.44890000             379316.29585000                            0
# 286     282.42070000             373995.44160200                            0
# 287      86.74590000             114913.80895500                            0
#
# [288 rows x 12 columns]

# %%
klines_dataframe.index = np.arange(klines_dataframe.shape[0])

# %%
closing_price = klines_dataframe['Close']

# %%
# Calculate the rolling mean and standard deviation
rolling_mean = closing_price.rolling(time_period).mean()
rolling_std = closing_price.rolling(time_period).std()

# %%
# Calculate the upper and lower bands
upper_band = rolling_mean + num_std_dev * rolling_std
lower_band = rolling_mean - num_std_dev * rolling_std

# %%
plt.plot(closing_price, label='Close')
plt.legend()
plt.show()
